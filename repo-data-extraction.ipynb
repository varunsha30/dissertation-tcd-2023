# %%
import pydriller
import pandas as pd
import json

# %%
repo_json = json.loads(open('data/top-pypi-packages-30-days.json').read())

# %%
repo_df = pd.read_csv()
# Out:
# {'last_update': '2023-08-01 08:13:19',
#  'query': {'bytes_billed': 577262059520,
#   'bytes_processed': 577261987886,
#   'cached': False,
#   'estimated_cost': '2.63'},
#  'rows': [{'download_count': 719072639, 'project': 'boto3'},
#   {'download_count': 329215565, 'project': 'urllib3'},
#   {'download_count': 320415214, 'project': 'botocore'},
#   {'download_count': 284144318, 'project': 'requests'},
#   {'download_count': 246176073, 'project': 'setuptools'},
#   {'download_count': 235247237, 'project': 'charset-normalizer'},
#   {'download_count': 235188968, 'project': 'typing-extensions'},
#   {'download_count': 224495508, 'project': 'awscli'},
#   {'download_count': 220042614, 'project': 'certifi'},
#   {'download_count': 201417158, 'project': 's3transfer'},
#   {'download_count': 196057078, 'project': 'python-dateutil'},
#   {'download_count': 193995592, 'project': 'idna'},
#   {'download_count': 185248986, 'project': 'google-api-core'},
# ...
